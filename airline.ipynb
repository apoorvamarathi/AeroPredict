# %%
import pandas as pd

# Load original dataset
df = pd.read_csv("C:\Users\Admin\SkyIntel\On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2025_1\On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2025_1.csv")

# Select only needed columns
selected_columns = [
    "Quarter",
    "Month",
    "DayofMonth",
    "DayOfWeek",
    "CRSDepTime",
    "CRSArrTime",
    "Distance",
    "Reporting_Airline",
    "Origin",
    "Dest",
    "ArrDelayMinutes"
]

df_clean = df[selected_columns]

print(df_clean.head())
